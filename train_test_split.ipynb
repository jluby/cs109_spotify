# %% [markdown]
# ## Spotify Train Test Splitting
#
# This notebook splits the full data into training and test sets.

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
np.random.seed(62)
df = pd.read_csv('data/final_spotify_data.csv')

# %%
df.head()
# Out:
#                  track_id                album_id  track_number  track_count  \
# 0  47HusOVsGPUcsJtMq40aRd  3hl2uaqB2zBZdetkeATUBe             2           13
# 1  74fXmxkP8507tIXYkVbKHM  3aqSysSJTyqHNyyiDiNGsI             2           14
# 2  6cf6rLb8qcklvJv90W6HCW  1KlU96Hw9nlvqpBPlSqcTV            19           22
# 3  1Ic1ugEU9PT8RvNippxDSG  2X8CnmJ7E4OgCQenKJSNrs             3            9
# 4  4kln61xMRKk2bwgrCXY4cV  2G6chemqdiNHxEw1ucZ7pw             7           14
#
#    duration  explicit  track_pop  album_pop  comparative_pop  danceability  \
# 0    357812         0         37         29         8.666667         0.843
# 1    356680         0          0          0         0.000000         0.719
# 2    220320         0         50         69       -19.904762         0.730
# 3    275360         0         16         12         4.500000         0.740
# 4    289373         0         33         48       -16.153846         0.577
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.460   -13.512       0.0540       0.00891           0.00247     0.132
# 1   0.849    -8.704       0.0555       0.05420           0.93000     0.702
# 2   0.587    -5.815       0.0283       0.30600           0.00000     0.143
# 3   0.956    -5.205       0.0861       0.34200           0.12200     0.630
# 4   0.458    -7.115       0.0338       0.02200           0.00422     0.084
#
#    valence    tempo
# 0   0.8400  109.123
# 1   0.0675  139.976
# 2   0.6490  125.070
# 3   0.1930  112.004
# 4   0.3950  127.330

# %%
df.columns
# Out:
# Index(['track_id', 'album_id', 'track_number', 'track_count', 'duration',
#        'explicit', 'track_pop', 'album_pop', 'comparative_pop', 'danceability',
#        'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(df.loc[:, df.columns != 'comparative_pop'], 
                                                         df.comparative_pop, test_size=0.2, 
                                                         random_state = 62, 
                                                         stratify = df.explicit)

# %%
X_train['comparative_pop'] = y_train

# %%
X_test['comparative_pop'] = y_test

# %%
X_train.head()
# Out:
#                       track_id                album_id  track_number  \
# 144409  3FVunrxKMJKPvDxnRttGci  0V8UU4es3kdF1djFZKlduq             8
# 28077   4LQNFT3PncoZ9WgZasPSSo  0F9EVGAk5Pi7um5YRPNgsO            11
# 65677   5ylBnaUYbWixo1ptaaWP2P  2wV8aQLr32lVSeTHDaEC0I            12
# 148353  48gzGGNiaTawmhN6Gkhmp9  2xYfsxlu6Qg4dlC3ShGIsP             1
# 60069   6zlSNFZjKhLi6KcMAd0X1s  19Gy0qg8XCbCvnRo5GtrNU             7
#
#         track_count  duration  explicit  track_pop  album_pop  danceability  \
# 144409           12    329175         1         42         53         0.819
# 28077            11    161200         0         15         22         0.486
# 65677            13    272066         0         26         40         0.433
# 148353            5   1310000         0          6          6         0.232
# 60069            13    190893         0         11         17         0.543
#
#         energy  loudness  speechiness  acousticness  instrumentalness  \
# 144409   0.529   -11.540       0.0714       0.03510          0.051700
# 28077    0.497    -7.575       0.0403       0.64600          0.000000
# 65677    0.502    -6.157       0.0278       0.00401          0.000004
# 148353   0.203   -21.255       0.0385       0.96400          0.893000
# 60069    0.158   -11.656       0.0328       0.92300          0.876000
#
#         liveness  valence    tempo  comparative_pop
# 144409    0.1830   0.5620  114.987       -12.000000
# 28077     0.1650   0.6640   84.113        -7.700000
# 65677     0.0725   0.0380   68.009       -15.166667
# 148353    0.1870   0.0727  151.676         0.000000
# 60069     0.0987   0.0587   80.041        -6.500000

# %%
X_test.head()
# Out:
#                       track_id                album_id  track_number  \
# 40215   4HPYBv8o3tzRI4BDLhPMmX  0iZZwv2fp5uF8hTYFNWFbW             6
# 133056  4JQSMg83F8qYwSBt5xOXsQ  1ciAVKFdlpLi2eGDlXv6Bo             2
# 100015  0FU2aPc9u6Ae2klbFsgbkI  0YaeFHEYGpdzdFIxDRFvCv            12
# 23930   2wgk0vMQCnwkETPJiqsQTt  2gDCBa5P6SnAaY0cadefQS             3
# 19082   5gTuRkjPru8nt2wH2xToG4  6oYPDF3t8SJ8zjWva4CRAL            19
#
#         track_count  duration  explicit  track_pop  album_pop  danceability  \
# 40215            13    370426         0          2         10         0.495
# 133056           17    225146         0         61         57         0.561
# 100015           15    371320         0         34         50         0.478
# 23930            14    301813         0         43         54         0.528
# 19082            19    276600         0          7         18         0.587
#
#         energy  loudness  speechiness  acousticness  instrumentalness  \
# 40215    0.164   -17.273       0.0284       0.81900          0.001640
# 133056   0.707    -4.910       0.0465       0.00114          0.000000
# 100015   0.611    -5.929       0.0299       0.01950          0.064900
# 23930    0.808    -5.198       0.0504       0.05450          0.000008
# 19082    0.629    -7.439       0.0424       0.18300          0.000000
#
#         liveness  valence    tempo  comparative_pop
# 40215     0.0800    0.240   90.854        -8.666667
# 133056    0.1120    0.386   91.943         4.250000
# 100015    0.1640    0.558   62.022       -17.142857
# 23930     0.0730    0.649  154.948       -11.846154
# 19082     0.0686    0.425  114.993       -11.611111

# %%
len(X_train) + len(X_test) == len(df)
# Out:
# True

# %%
# Write the different sets to CSVs
X_train.to_csv("data/training.csv", index=False)
X_test.to_csv("data/testing.csv", index=False)
